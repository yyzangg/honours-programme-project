# %%
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

# %%
file_path = "myData2.parquet"
df = pd.read_parquet(file_path)

# %%
# Size of the Dataset
num_rows, num_columns = df.shape
print(f"Size of the Dataset: {num_rows} rows x {num_columns} columns\n")
# Out:
# Size of the Dataset: 461500 rows x 99 columns

# %%
# Column Names
# column_names = df.columns.tolist()
# print("Column Names:", column_names, "\n")

# Data Types
# data_types = df.dtypes
# print("Data Types:")
# print(data_types, "\n")

df.info(max_cols=100)

# # Description of Columns
# column_descriptions = {
#     "column_name": [],
#     "description": []
# }

# Add descriptions for each column as needed
# Example:
# column_descriptions["column_name"].append("ColumnName")
# column_descriptions["description"].append("Description of the column")

# # Print column descriptions
# print("Description of Columns:")
# for col, description in zip(column_descriptions["column_name"], column_descriptions["description"]):
#     print(f"{col}: {description}")
# print()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 461500 entries, 0 to 461499
# Data columns (total 99 columns):
#  #   Column                                          Non-Null Count   Dtype
# ---  ------                                          --------------   -----
#  0   prom_id                                         461500 non-null  object
#  1   timestamp                                       461500 non-null  datetime64[ns]
#  2   prom_node                                       461500 non-null  object
#  3   node_time_seconds                               461500 non-null  float64
#  4   node_load15                                     461500 non-null  float64
#  5   surfsara_power_usage                            461500 non-null  float64
#  6   up                                              461500 non-null  float64
#  7   node_netstat_Tcp_OutSegs                        461500 non-null  float64
#  8   node_netstat_Tcp_InErrs                         461500 non-null  float64
# ...

# %%
# Summary Statistics
summary_statistics = df.describe()
print("Summary Statistics:")
print(summary_statistics, "\n")
# Out:
# Summary Statistics:
#                            timestamp  node_time_seconds    node_load15  \
# count                         461500       4.615000e+05  461500.000000
# mean   2022-09-06 21:07:40.009469184       1.662499e+09      11.797828
# min              2022-07-04 07:36:00       1.656930e+09       0.000000
# 25%       2022-08-19 20:47:22.500000       1.660940e+09       3.480000
# 50%              2022-09-09 07:33:15       1.662710e+09      13.180000
# 75%       2022-09-22 15:27:07.500000       1.663860e+09      15.140000
# max              2022-10-27 05:51:30       1.666850e+09     223.110000
# std                              NaN       2.533169e+06      13.984443
#
#        surfsara_power_usage             up  node_netstat_Tcp_OutSegs  \
# count         461500.000000  461500.000000              4.615000e+05
# mean             118.244464       0.999881              5.607324e+09
# min               32.000000       0.000000              4.123000e+03
# ...

# %%
# Sample Data
sample_data = df.head()
print("Sample Data:")
print(sample_data)
# Out:
# Sample Data:
#    prom_id           timestamp prom_node  node_time_seconds  node_load15  \
# 0  7247237 2022-07-04 07:36:00     r10n1       1.656930e+09         0.01
# 1  7247238 2022-07-04 07:36:30     r10n1       1.656930e+09         0.04
# 2  7247239 2022-07-04 07:37:00     r10n1       1.656930e+09         0.07
# 3  7247240 2022-07-04 07:37:30     r10n1       1.656930e+09         0.10
# 4  7247241 2022-07-04 07:38:00     r10n1       1.656930e+09         0.32
#
#    surfsara_power_usage   up  node_netstat_Tcp_OutSegs  \
# 0                  36.0  1.0              4.441490e+10
# 1                  92.0  1.0              4.441500e+10
# 2                  92.0  1.0              4.441500e+10
# 3                  92.0  1.0              4.441500e+10
# 4                  92.0  1.0              4.441510e+10
#
#    node_netstat_Tcp_InErrs  node_context_switches_total  ...  numnodes  \
# 0                      3.0                 5.004180e+11  ...       1.0
# ...

# %%
df
# Out:
#           prom_id           timestamp prom_node  node_time_seconds  \
# 0         7247237 2022-07-04 07:36:00     r10n1       1.656930e+09
# 1         7247238 2022-07-04 07:36:30     r10n1       1.656930e+09
# 2         7247239 2022-07-04 07:37:00     r10n1       1.656930e+09
# 3         7247240 2022-07-04 07:37:30     r10n1       1.656930e+09
# 4         7247241 2022-07-04 07:38:00     r10n1       1.656930e+09
# ...           ...                 ...       ...                ...
# 461495  122471865 2022-10-27 05:51:00     r10n1       1.666850e+09
# 461496  122471865 2022-10-27 05:51:00     r10n1       1.666850e+09
# 461497  122471866 2022-10-27 05:51:30     r10n1       1.666850e+09
# 461498  122471866 2022-10-27 05:51:30     r10n1       1.666850e+09
# 461499  122471866 2022-10-27 05:51:30     r10n1       1.666850e+09
#
#         node_load15  surfsara_power_usage   up  node_netstat_Tcp_OutSegs  \
# 0              0.01                  36.0  1.0              4.441490e+10
# ...
