# %%
import pandas as pd
import numpy as np
import time
import torch
import torch.nn as nn
from tcn import TCN
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import LSTM, Dense, Concatenate, Attention, Dropout
from tensorflow.keras.callbacks import EarlyStopping            
from tensorflow.keras.optimizers import Adam
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from memory_profiler import memory_usage
import warnings

warnings.filterwarnings('ignore')

# %%
file_path = "myData2.parquet"
df = pd.read_parquet(file_path)

# %%
selected_features = ['timestamp_seconds', 
                     'node_memory_Percpu_bytes', 
                     'node_context_switches_total', 
                     'surfsara_power_usage', 
                     'node_netstat_Tcp_InSegs', 
                     'node_netstat_Tcp_OutSegs', 
                     'node_network_transmit_packets_total-sum', 
                     'node_filesystem_size_bytes-sum', 
                     'node_filesystem_files-sum', 
                     'node_memory_MemFree_bytes', 
                     'node_netstat_Tcp_InErrs']
# FixMe

# %%
# Define time intervals
time_intervals = {'minute': '1T', 'hour': '1H', 'day': '1D'}

# Set sequence length
sequence_length = 30

# Number of time steps to predict into the future
prediction_steps = 7

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %%
# Function to prepare data
def prepare_data(data, time_interval):
    data.set_index('timestamp', inplace=True)
    data_resampled = data.resample(time_interval).sum()
    
    target_min = data_resampled['target'].min()
    target_max = data_resampled['target'].max()
    data_resampled['target'] = (data_resampled['target'] - target_min) / (target_max - target_min)
    
    return data_resampled

# Function to create sequences
def create_sequences(data, sequence_length):
    sequences, targets = [], []
    for i in range(len(data) - sequence_length):
        seq = data.iloc[i:i+sequence_length].values
        target = data.iloc[i+sequence_length]['target']
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

# %%
# Function to create a hybrid model with attention mechanism
def create_attention_hybrid_model(lstm_model, tcn_model):
    lstm_input = lstm_model.input
    tcn_input = tcn_model.input

    # Get the output layers of both models
    lstm_output = lstm_model.layers[-1].output
    tcn_output = tcn_model.layers[-1].output

    # Use Attention mechanism to combine outputs
    attention = Attention()([lstm_output, tcn_output])
    merged = Concatenate()([lstm_output, tcn_output, attention])

    # Add a dense layer for the final prediction
    merged = Dense(1, activation='sigmoid')(merged)

    # Create the ensemble model
    ensemble_model = Model(inputs=[lstm_input, tcn_input], outputs=merged)

    # Compile the model
    ensemble_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

    return ensemble_model

# %%
# Function to make predictions on new data for the hybrid model
def predict_future_failures_hybrid(model, input_data_lstm, input_data_tcn, sequence_length, prediction_steps):
    predictions = []

    for _ in range(prediction_steps):
        # Make predictions for the next time step using both LSTM and TCN models
        prediction = model.predict([input_data_lstm.reshape(1, sequence_length, input_data_lstm.shape[1]),
                                    input_data_tcn.reshape(1, sequence_length, input_data_tcn.shape[1])])
        predictions.append(prediction[0, 0])

        # Shift the input data by one time step and append the new prediction
        input_data_lstm = np.roll(input_data_lstm, shift=-1, axis=0)
        input_data_lstm[-1, -1] = prediction[0, 0]

        input_data_tcn = np.roll(input_data_tcn, shift=-1, axis=0)
        input_data_tcn[-1, -1] = prediction[0, 0]

    return predictions

# %% [markdown]
# # 30 days -> 7 days

# %%
# Extract relevant columns
df_selected = df[['timestamp', 'state'] + selected_features].copy()

# Encode the target variable 'state' to binary (0 for "COMPLETED", 1 otherwise)
df_selected['target'] = (df_selected['state'] != 'COMPLETED').astype(int)

# Drop the original 'state' column
df_selected.drop('state', axis=1, inplace=True)

# Normalize selected features
scaler = MinMaxScaler()
df_selected[selected_features] = scaler.fit_transform(df_selected[selected_features])

# %%
# Prepare data with daily intervals
data_day = prepare_data(df_selected, time_intervals['day'])

# Create sequences and targets
sequences_day, targets_day = create_sequences(data_day, sequence_length)

# Define the index to split the data
split_index_day = int(len(sequences_day) * 0.7)  # Use 70% of the data for training

# Split the data into training and testing sets
X_train_day, X_test_day = sequences_day[:split_index_day], sequences_day[split_index_day:]
y_train_day, y_test_day = targets_day[:split_index_day], targets_day[split_index_day:]

# Build the LSTM model
lstm_model_day = Sequential()
lstm_model_day.add(LSTM(10, input_shape=(X_train_day.shape[1], X_train_day.shape[2])))
lstm_model_day.add(Dense(1, activation='sigmoid'))
optimizer = Adam(learning_rate=0.0005)
lstm_model_day.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['mean_squared_error'])

# Train the model
lstm_model_day.fit(X_train_day, y_train_day, epochs=20, batch_size=32, validation_split=0.1)

# Build the TCN model
tcn_model_day = Sequential([
    TCN(input_shape=(sequence_length, X_train_day.shape[2])),
    Dense(1, activation='sigmoid')
])
tcn_model_day.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

# Train the model
tcn_model_day.fit(X_train_day, y_train_day, epochs=20, batch_size=32, validation_split=0.15)

# Create the hybrid model
hybrid_model_attention_day = create_attention_hybrid_model(lstm_model_day, tcn_model_day)

# Train the hybrid model with both LSTM and TCN data
history_day = hybrid_model_attention_day.fit([X_train_day, X_train_day], y_train_day, epochs=20, batch_size=32, validation_split=0.15)
# Out:
# Epoch 1/20
# 2/2 [==============================] - 2s 480ms/step - loss: 0.0946 - mean_squared_error: 0.0946 - val_loss: 0.0897 - val_mean_squared_error: 0.0897
# Epoch 2/20
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0942 - mean_squared_error: 0.0942 - val_loss: 0.0892 - val_mean_squared_error: 0.0892
# Epoch 3/20
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0936 - mean_squared_error: 0.0936 - val_loss: 0.0888 - val_mean_squared_error: 0.0888
# Epoch 4/20
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0932 - mean_squared_error: 0.0932 - val_loss: 0.0884 - val_mean_squared_error: 0.0884
# Epoch 5/20
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0929 - mean_squared_error: 0.0929 - val_loss: 0.0879 - val_mean_squared_error: 0.0879
# Epoch 6/20
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0925 - mean_squared_error: 0.0925 - val_loss: 0.0875 - val_mean_squared_error: 0.0875
# Epoch 7/20
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0921 - mean_squared_error: 0.0921 - val_loss: 0.0871 - val_mean_squared_error: 0.0871
# Epoch 8/20
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0918 - mean_squared_error: 0.0918 - val_loss: 0.0867 - val_mean_squared_error: 0.0867
# Epoch 9/20
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0914 - mean_squared_error: 0.0914 - val_loss: 0.0863 - val_mean_squared_error: 0.0863
# Epoch 10/20
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0910 - mean_squared_error: 0.0910 - val_loss: 0.0859 - val_mean_squared_error: 0.0859
# Epoch 11/20
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0906 - mean_squared_error: 0.0906 - val_loss: 0.0855 - val_mean_squared_error: 0.0855
# Epoch 12/20
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0902 - mean_squared_error: 0.0902 - val_loss: 0.0851 - val_mean_squared_error: 0.0851
# Epoch 13/20
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0899 - mean_squared_error: 0.0899 - val_loss: 0.0847 - val_mean_squared_error: 0.0847
# Epoch 14/20
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0896 - mean_squared_error: 0.0896 - val_loss: 0.0843 - val_mean_squared_error: 0.0843
# Epoch 15/20
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0885 - mean_squared_error: 0.0885 - val_loss: 0.0839 - val_mean_squared_error: 0.0839
# Epoch 16/20
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0778 - mean_squared_error: 0.0778 - val_loss: 0.0835 - val_mean_squared_error: 0.0835
# Epoch 17/20
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0728 - mean_squared_error: 0.0728 - val_loss: 0.0831 - val_mean_squared_error: 0.0831
# Epoch 18/20
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0725 - mean_squared_error: 0.0725 - val_loss: 0.0827 - val_mean_squared_error: 0.0827
# Epoch 19/20
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0721 - mean_squared_error: 0.0721 - val_loss: 0.0822 - val_mean_squared_error: 0.0822
# Epoch 20/20
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0717 - mean_squared_error: 0.0717 - val_loss: 0.0819 - val_mean_squared_error: 0.0819
# Epoch 1/20
# 2/2 [==============================] - 3s 463ms/step - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 2/20
# 2/2 [==============================] - 0s 87ms/step - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 3/20
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 4/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 5/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 6/20
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 7/20
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 8/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 9/20
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 10/20
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 11/20
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 12/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 13/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 14/20
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 15/20
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 16/20
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 17/20
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 18/20
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 19/20
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 20/20
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0351 - mean_squared_error: 0.0351 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 1/20
# 2/2 [==============================] - 5s 836ms/step - loss: 0.2508 - mean_squared_error: 0.2508 - val_loss: 0.3260 - val_mean_squared_error: 0.3260
# Epoch 2/20
# 2/2 [==============================] - 0s 88ms/step - loss: 0.2498 - mean_squared_error: 0.2498 - val_loss: 0.3248 - val_mean_squared_error: 0.3248
# Epoch 3/20
# 2/2 [==============================] - 0s 88ms/step - loss: 0.2488 - mean_squared_error: 0.2488 - val_loss: 0.3237 - val_mean_squared_error: 0.3237
# Epoch 4/20
# 2/2 [==============================] - 0s 88ms/step - loss: 0.2479 - mean_squared_error: 0.2479 - val_loss: 0.3225 - val_mean_squared_error: 0.3225
# Epoch 5/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.2469 - mean_squared_error: 0.2469 - val_loss: 0.3213 - val_mean_squared_error: 0.3213
# Epoch 6/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.2459 - mean_squared_error: 0.2459 - val_loss: 0.3201 - val_mean_squared_error: 0.3201
# Epoch 7/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.2446 - mean_squared_error: 0.2446 - val_loss: 0.3190 - val_mean_squared_error: 0.3190
# Epoch 8/20
# 2/2 [==============================] - 0s 83ms/step - loss: 0.2432 - mean_squared_error: 0.2432 - val_loss: 0.3178 - val_mean_squared_error: 0.3178
# Epoch 9/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.2414 - mean_squared_error: 0.2414 - val_loss: 0.3166 - val_mean_squared_error: 0.3166
# Epoch 10/20
# 2/2 [==============================] - 0s 83ms/step - loss: 0.2404 - mean_squared_error: 0.2404 - val_loss: 0.3155 - val_mean_squared_error: 0.3155
# Epoch 11/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.2395 - mean_squared_error: 0.2395 - val_loss: 0.3143 - val_mean_squared_error: 0.3143
# Epoch 12/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.2385 - mean_squared_error: 0.2385 - val_loss: 0.3132 - val_mean_squared_error: 0.3132
# Epoch 13/20
# 2/2 [==============================] - 0s 85ms/step - loss: 0.2374 - mean_squared_error: 0.2374 - val_loss: 0.3121 - val_mean_squared_error: 0.3121
# Epoch 14/20
# 2/2 [==============================] - 0s 83ms/step - loss: 0.2365 - mean_squared_error: 0.2365 - val_loss: 0.3109 - val_mean_squared_error: 0.3109
# Epoch 15/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.2356 - mean_squared_error: 0.2356 - val_loss: 0.3098 - val_mean_squared_error: 0.3098
# Epoch 16/20
# 2/2 [==============================] - 0s 84ms/step - loss: 0.2345 - mean_squared_error: 0.2345 - val_loss: 0.3087 - val_mean_squared_error: 0.3087
# Epoch 17/20
# 2/2 [==============================] - 0s 86ms/step - loss: 0.2335 - mean_squared_error: 0.2335 - val_loss: 0.3076 - val_mean_squared_error: 0.3076
# Epoch 18/20
# 2/2 [==============================] - 0s 85ms/step - loss: 0.2326 - mean_squared_error: 0.2326 - val_loss: 0.3065 - val_mean_squared_error: 0.3065
# Epoch 19/20
# 2/2 [==============================] - 0s 85ms/step - loss: 0.2317 - mean_squared_error: 0.2317 - val_loss: 0.3054 - val_mean_squared_error: 0.3054
# Epoch 20/20
# 2/2 [==============================] - 0s 82ms/step - loss: 0.2308 - mean_squared_error: 0.2308 - val_loss: 0.3043 - val_mean_squared_error: 0.3043

# %% [markdown]
# ## Performance_Day

# %%
# Evaluate the model using Mean Squared Error
mse_day = hybrid_model_attention_day.evaluate([X_test_day, X_test_day], y_test_day, verbose=0)[1]
print(f'Mean Squared Error: {mse_day:.4f}\n')
# Out:
# Mean Squared Error: 0.1729

# %%
# Evaluate model on test data
y_pred_day = hybrid_model_attention_day.predict([X_test_day, X_test_day])

# Calculate Root Mean Squared Error
rmse_day = mean_squared_error(y_test_day, y_pred_day, squared=False)
print(f'Root Mean Squared Error (RMSE): {rmse_day:.4f}\n')

# Calculate Mean Absolute Error
mae_day = mean_absolute_error(y_test_day, y_pred_day)
print(f'Mean Abosolute Error: {mae_day:.4f}\n')

# Calculate R-squared
r2_day = r2_score(y_test_day, y_pred_day)
print(f'R-squared (R2): {r2_day:.4f}\n')
# Out:
# 1/1 [==============================] - 1s 686ms/step
# Root Mean Squared Error (RMSE): 0.4158
#
# Mean Abosolute Error: 0.3835
#
# R-squared (R2): -2.0643

# %% [markdown]
# ### Training and Validation Loss Plot

# %%
# Plot training and validation loss
plt.plot(history_day.history['loss'], label='Training Loss')
plt.plot(history_day.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Predicted Failures vs. True Failures Plot

# %%
y_test_day.shape
# FixMe
# Out:
# (26,)

# %%
index_day = 8  # Can be any valid starting point

input_data_day = X_test_day[index_day]

# Make predictions
predicted_failures_day = predict_future_failures_hybrid(hybrid_model_attention_day, input_data_day, input_data_day, sequence_length, prediction_steps)

# # Denormalize the predicted failures 
# predicted_failures_denormalized_day = np.array(predicted_failures_day) * (target_max_day - target_min_day) + target_min_day

# Get the true failures for the specified number of days
true_failures_day = y_test_day[index_day:index_day + prediction_steps]

# Print the predicted failures
print("Predicted failures for the next 7 days:")
print(predicted_failures_day)

# Evaluate the predictions using Mean Squared Error
mse_predictions = np.mean((predicted_failures_day - true_failures_day)**2)
print(f'\nMean Squared Error for Predictions: {mse_predictions:.4f}\n')

# Evaluate the predictions using Mean Absolute Error
mae_predictions = np.mean(np.abs(predicted_failures_day - true_failures_day))
print(f'Mean Absolute Error for Predictions: {mae_predictions:.4f}')

# Plot predicted failures vs. true failures
plt.figure(figsize=(10, 6))
plt.plot(predicted_failures_day, label='Predicted Failures', marker='o')
plt.plot(true_failures_day, label='True Failures', marker='x')
plt.xlabel('Days')
plt.ylabel('Number of Failures')
plt.title('Predicted Failures vs. True Failures')
plt.legend()
plt.ylim(-1, 4)
plt.grid(True)
plt.show()
# Out:
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted failures for the next 7 days:
# [0.45853505, 0.46128476, 0.46128476, 0.46128476, 0.46128476, 0.46128476, 0.46128476]
#
# Mean Squared Error for Predictions: 0.1218
#
# Mean Absolute Error for Predictions: 0.3139

# %%
# index_day = 0  # Can be any valid starting point

# input_data_day = X_test_day[index_day]
# previous_true_failures_day = y_test_day[index_day:index_day + sequence_length]

# # Make predictions
# predicted_failures_day = predict_future_failures_hybrid(hybrid_model_attention_day, input_data_day, input_data_day, sequence_length, prediction_steps)

# predicted_failures_with_previous_day = np.concatenate([previous_true_failures_day, predicted_failures_day])

# # Get the true failures for the specified number of days
# true_failures_day = y_test_day[index_day + sequence_length:index_day + sequence_length + prediction_steps]

# true_failures_with_previous_day = np.concatenate([previous_true_failures_day, true_failures_day])

# # Print the predicted failures
# print("Predicted failures for the next 7 days:")
# print(predicted_failures_day)

# # Evaluate the predictions using Mean Squared Error
# mse_predictions = np.mean((predicted_failures_day - true_failures_day)**2)
# print(f'\nMean Squared Error for Predictions: {mse_predictions:.4f}\n')

# # Evaluate the predictions using Mean Absolute Error
# mae_predictions = np.mean(np.abs(predicted_failures_day - true_failures_day))
# print(f'Mean Absolute Error for Predictions: {mae_predictions:.4f}')

# # Plot predicted failures vs. true failures
# plt.figure(figsize=(10, 6))
# plt.plot(predicted_failures_with_previous_day, label='Predicted Failures', marker='o')
# plt.plot(true_failures_with_previous_day, label='True Failures', marker='x')
# plt.xlabel('Days')
# plt.ylabel('Number of Failures')
# plt.title('Predicted Failures vs. True Failures')
# plt.legend()
# plt.ylim(-1, 2)
# plt.grid(True)
# plt.show()

# %% [markdown]
# # 30 hours -> 7 hours

# %%
# Extract relevant columns
df_selected = df[['timestamp', 'state'] + selected_features].copy()

# Encode the target variable 'state' to binary (0 for "COMPLETED", 1 otherwise)
df_selected['target'] = (df_selected['state'] != 'COMPLETED').astype(int)

# Drop the original 'state' column
df_selected.drop('state', axis=1, inplace=True)

# Normalize selected features
scaler = MinMaxScaler()
df_selected[selected_features] = scaler.fit_transform(df_selected[selected_features])

# %%
# Prepare data with hourly intervals
data_hour = prepare_data(df_selected, time_intervals['hour'])

# Create sequences and targets
sequences_hour, targets_hour = create_sequences(data_hour, sequence_length)

# Define the index to split the data
split_index_hour = int(len(sequences_hour) * 0.7)  # Use 70% of the data for training

# Split the data into training and testing sets
X_train_hour, X_test_hour = sequences_hour[:split_index_hour], sequences_hour[split_index_hour:]
y_train_hour, y_test_hour = targets_hour[:split_index_hour], targets_hour[split_index_hour:]

# Build the LSTM model
lstm_model_hour = Sequential()
lstm_model_hour.add(LSTM(20, input_shape=(X_train_hour.shape[1], X_train_hour.shape[2])))
lstm_model_hour.add(Dense(1, activation='sigmoid'))
lstm_model_hour.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

# Train the model
lstm_model_hour.fit(X_train_hour, y_train_hour, epochs=10, batch_size=16, validation_split=0.15)

# Build the TCN model
tcn_model_hour = Sequential([
    TCN(input_shape=(sequence_length, X_train_hour.shape[2])),
    Dense(1, activation='sigmoid')
])
tcn_model_hour.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

# Train the model
tcn_model_hour.fit(X_train_hour, y_train_hour, epochs=20, batch_size=32, validation_split=0.1)

# Create the hybrid model
hybrid_model_attention_hour = create_attention_hybrid_model(lstm_model_hour, tcn_model_hour)

# Train the hybrid model with both LSTM and TCN data
history_hour = hybrid_model_attention_hour.fit([X_train_hour, X_train_hour], y_train_hour, epochs=20, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/10
# 102/102 [==============================] - 4s 22ms/step - loss: 0.0566 - mean_squared_error: 0.0566 - val_loss: 0.0093 - val_mean_squared_error: 0.0093
# Epoch 2/10
# 102/102 [==============================] - 2s 17ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 3/10
# 102/102 [==============================] - 2s 17ms/step - loss: 6.3840e-04 - mean_squared_error: 6.3840e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 4/10
# 102/102 [==============================] - 2s 18ms/step - loss: 4.4237e-04 - mean_squared_error: 4.4237e-04 - val_loss: 8.9912e-04 - val_mean_squared_error: 8.9912e-04
# Epoch 5/10
# 102/102 [==============================] - 2s 16ms/step - loss: 3.6736e-04 - mean_squared_error: 3.6736e-04 - val_loss: 7.6952e-04 - val_mean_squared_error: 7.6952e-04
# Epoch 6/10
# 102/102 [==============================] - 2s 17ms/step - loss: 3.3345e-04 - mean_squared_error: 3.3345e-04 - val_loss: 6.3302e-04 - val_mean_squared_error: 6.3302e-04
# Epoch 7/10
# 102/102 [==============================] - 2s 16ms/step - loss: 3.1839e-04 - mean_squared_error: 3.1839e-04 - val_loss: 6.2106e-04 - val_mean_squared_error: 6.2106e-04
# Epoch 8/10
# 102/102 [==============================] - 2s 16ms/step - loss: 3.0056e-04 - mean_squared_error: 3.0056e-04 - val_loss: 6.6814e-04 - val_mean_squared_error: 6.6814e-04
# Epoch 9/10
# 102/102 [==============================] - 2s 16ms/step - loss: 2.9300e-04 - mean_squared_error: 2.9300e-04 - val_loss: 7.3580e-04 - val_mean_squared_error: 7.3580e-04
# Epoch 10/10
# 102/102 [==============================] - 2s 16ms/step - loss: 2.8522e-04 - mean_squared_error: 2.8522e-04 - val_loss: 7.3114e-04 - val_mean_squared_error: 7.3114e-04
# Epoch 1/20
# 54/54 [==============================] - 5s 46ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 3.4416e-06 - val_mean_squared_error: 3.4416e-06
# Epoch 2/20
# 54/54 [==============================] - 2s 36ms/step - loss: 8.1070e-04 - mean_squared_error: 8.1070e-04 - val_loss: 3.4416e-06 - val_mean_squared_error: 3.4416e-06
# Epoch 3/20
# 54/54 [==============================] - 2s 36ms/step - loss: 8.1070e-04 - mean_squared_error: 8.1070e-04 - val_loss: 3.4416e-06 - val_mean_squared_error: 3.4416e-06
# Epoch 4/20
# 54/54 [==============================] - 2s 36ms/step - loss: 8.1070e-04 - mean_squared_error: 8.1070e-04 - val_loss: 3.4416e-06 - val_mean_squared_error: 3.4416e-06
# Epoch 5/20
# 54/54 [==============================] - 2s 38ms/step - loss: 8.1070e-04 - mean_squared_error: 8.1070e-04 - val_loss: 3.4416e-06 - val_mean_squared_error: 3.4416e-06
# Epoch 6/20
# 54/54 [==============================] - 2s 42ms/step - loss: 8.1070e-04 - mean_squared_error: 8.1070e-04 - val_loss: 3.4416e-06 - val_mean_squared_error: 3.4416e-06
# Epoch 7/20
# 54/54 [==============================] - 2s 41ms/step - loss: 8.1070e-04 - mean_squared_error: 8.1070e-04 - val_loss: 3.4416e-06 - val_mean_squared_error: 3.4416e-06
# Epoch 8/20
# 54/54 [==============================] - 2s 41ms/step - loss: 8.1070e-04 - mean_squared_error: 8.1070e-04 - val_loss: 3.4416e-06 - val_mean_squared_error: 3.4416e-06
# Epoch 9/20
# 54/54 [==============================] - 2s 40ms/step - loss: 8.1070e-04 - mean_squared_error: 8.1070e-04 - val_loss: 3.4416e-06 - val_mean_squared_error: 3.4416e-06
# Epoch 10/20
# 54/54 [==============================] - 2s 42ms/step - loss: 8.1070e-04 - mean_squared_error: 8.1070e-04 - val_loss: 3.4416e-06 - val_mean_squared_error: 3.4416e-06
# Epoch 11/20
# 54/54 [==============================] - 2s 42ms/step - loss: 8.1070e-04 - mean_squared_error: 8.1070e-04 - val_loss: 3.4416e-06 - val_mean_squared_error: 3.4416e-06
# Epoch 12/20
# 54/54 [==============================] - 2s 40ms/step - loss: 8.1070e-04 - mean_squared_error: 8.1070e-04 - val_loss: 3.4416e-06 - val_mean_squared_error: 3.4416e-06
# Epoch 13/20
# 54/54 [==============================] - 2s 40ms/step - loss: 8.1070e-04 - mean_squared_error: 8.1070e-04 - val_loss: 3.4416e-06 - val_mean_squared_error: 3.4416e-06
# Epoch 14/20
# 54/54 [==============================] - 2s 41ms/step - loss: 8.1070e-04 - mean_squared_error: 8.1070e-04 - val_loss: 3.4416e-06 - val_mean_squared_error: 3.4416e-06
# Epoch 15/20
# 54/54 [==============================] - 2s 41ms/step - loss: 8.1070e-04 - mean_squared_error: 8.1070e-04 - val_loss: 3.4416e-06 - val_mean_squared_error: 3.4416e-06
# Epoch 16/20
# 54/54 [==============================] - 2s 42ms/step - loss: 8.1070e-04 - mean_squared_error: 8.1070e-04 - val_loss: 3.4416e-06 - val_mean_squared_error: 3.4416e-06
# Epoch 17/20
# 54/54 [==============================] - 2s 42ms/step - loss: 8.1070e-04 - mean_squared_error: 8.1070e-04 - val_loss: 3.4416e-06 - val_mean_squared_error: 3.4416e-06
# Epoch 18/20
# 54/54 [==============================] - 2s 42ms/step - loss: 8.1070e-04 - mean_squared_error: 8.1070e-04 - val_loss: 3.4416e-06 - val_mean_squared_error: 3.4416e-06
# Epoch 19/20
# 54/54 [==============================] - 2s 41ms/step - loss: 8.1070e-04 - mean_squared_error: 8.1070e-04 - val_loss: 3.4416e-06 - val_mean_squared_error: 3.4416e-06
# Epoch 20/20
# 54/54 [==============================] - 2s 40ms/step - loss: 8.1070e-04 - mean_squared_error: 8.1070e-04 - val_loss: 3.4416e-06 - val_mean_squared_error: 3.4416e-06
# Epoch 1/20
# 54/54 [==============================] - 8s 58ms/step - loss: 0.2289 - mean_squared_error: 0.2289 - val_loss: 0.2376 - val_mean_squared_error: 0.2376
# Epoch 2/20
# 54/54 [==============================] - 2s 44ms/step - loss: 0.2150 - mean_squared_error: 0.2150 - val_loss: 0.2243 - val_mean_squared_error: 0.2243
# Epoch 3/20
# 54/54 [==============================] - 2s 44ms/step - loss: 0.2028 - mean_squared_error: 0.2028 - val_loss: 0.2120 - val_mean_squared_error: 0.2120
# Epoch 4/20
# 54/54 [==============================] - 2s 45ms/step - loss: 0.1913 - mean_squared_error: 0.1913 - val_loss: 0.2004 - val_mean_squared_error: 0.2004
# Epoch 5/20
# 54/54 [==============================] - 2s 41ms/step - loss: 0.1805 - mean_squared_error: 0.1805 - val_loss: 0.1893 - val_mean_squared_error: 0.1893
# Epoch 6/20
# 54/54 [==============================] - 2s 44ms/step - loss: 0.1702 - mean_squared_error: 0.1702 - val_loss: 0.1789 - val_mean_squared_error: 0.1789
# Epoch 7/20
# 54/54 [==============================] - 2s 42ms/step - loss: 0.1604 - mean_squared_error: 0.1604 - val_loss: 0.1690 - val_mean_squared_error: 0.1690
# Epoch 8/20
# 54/54 [==============================] - 2s 43ms/step - loss: 0.1512 - mean_squared_error: 0.1512 - val_loss: 0.1597 - val_mean_squared_error: 0.1597
# Epoch 9/20
# 54/54 [==============================] - 2s 42ms/step - loss: 0.1426 - mean_squared_error: 0.1426 - val_loss: 0.1509 - val_mean_squared_error: 0.1509
# Epoch 10/20
# 54/54 [==============================] - 2s 43ms/step - loss: 0.1344 - mean_squared_error: 0.1344 - val_loss: 0.1426 - val_mean_squared_error: 0.1426
# Epoch 11/20
# 54/54 [==============================] - 2s 42ms/step - loss: 0.1267 - mean_squared_error: 0.1267 - val_loss: 0.1348 - val_mean_squared_error: 0.1348
# Epoch 12/20
# 54/54 [==============================] - 2s 43ms/step - loss: 0.1195 - mean_squared_error: 0.1195 - val_loss: 0.1275 - val_mean_squared_error: 0.1275
# Epoch 13/20
# 54/54 [==============================] - 2s 42ms/step - loss: 0.1127 - mean_squared_error: 0.1127 - val_loss: 0.1205 - val_mean_squared_error: 0.1205
# Epoch 14/20
# 54/54 [==============================] - 2s 42ms/step - loss: 0.1063 - mean_squared_error: 0.1063 - val_loss: 0.1141 - val_mean_squared_error: 0.1141
# Epoch 15/20
# 54/54 [==============================] - 2s 43ms/step - loss: 0.1003 - mean_squared_error: 0.1003 - val_loss: 0.1079 - val_mean_squared_error: 0.1079
# Epoch 16/20
# 54/54 [==============================] - 2s 44ms/step - loss: 0.0947 - mean_squared_error: 0.0947 - val_loss: 0.1022 - val_mean_squared_error: 0.1022
# Epoch 17/20
# 54/54 [==============================] - 2s 42ms/step - loss: 0.0895 - mean_squared_error: 0.0895 - val_loss: 0.0968 - val_mean_squared_error: 0.0968
# Epoch 18/20
# 54/54 [==============================] - 2s 40ms/step - loss: 0.0845 - mean_squared_error: 0.0845 - val_loss: 0.0918 - val_mean_squared_error: 0.0918
# Epoch 19/20
# 54/54 [==============================] - 2s 42ms/step - loss: 0.0799 - mean_squared_error: 0.0799 - val_loss: 0.0871 - val_mean_squared_error: 0.0871
# Epoch 20/20
# 54/54 [==============================] - 2s 41ms/step - loss: 0.0756 - mean_squared_error: 0.0756 - val_loss: 0.0826 - val_mean_squared_error: 0.0826

# %% [markdown]
# ## Performance_Hour

# %%
# Evaluate the model using Mean Squared Error
mse_hour = hybrid_model_attention_hour.evaluate([X_test_hour, X_test_hour], y_test_hour, verbose=0)[1]
print(f'Mean Squared Error: {mse_hour:.4f}\n')
# Out:
# Mean Squared Error: 0.0724

# %%
# Evaluate model on test data
y_pred_hour = hybrid_model_attention_hour.predict([X_test_hour, X_test_hour])

# Calculate Root Mean Squared Error
rmse_hour = mean_squared_error(y_test_hour, y_pred_hour, squared=False)
print(f'Root Mean Squared Error (RMSE): {rmse_hour:.4f}\n')

# Calculate Mean Absolute Error
mae_hour = mean_absolute_error(y_test_hour, y_pred_hour)
print(f'Mean Abosolute Error: {mae_hour:.4f}\n')

# Calculate R-squared
r2_hour = r2_score(y_test_hour, y_pred_hour)
print(f'R-squared (R2): {r2_hour:.4f}\n')
# Out:
# 26/26 [==============================] - 1s 18ms/step
# Root Mean Squared Error (RMSE): 0.2691
#
# Mean Abosolute Error: 0.2657
#
# R-squared (R2): -12.7517

# %% [markdown]
# ### Training and Validation Loss Plot

# %%
# Plot training and validation loss
plt.plot(history_hour.history['loss'], label='Training Loss')
plt.plot(history_hour.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Predicted Failures vs. True Failures Plot

# %%
index_hour = 30 # Can be any valid starting point

input_data_hour = X_test_hour[index_hour]
previous_true_failures_hour = y_test_hour[index_hour:index_hour + sequence_length]

# Make predictions
predicted_failures_hour = predict_future_failures_hybrid(hybrid_model_attention_day, input_data_hour, input_data_hour, sequence_length, prediction_steps)

predicted_failures_with_previous_hour = np.concatenate([previous_true_failures_hour, predicted_failures_hour])

# Get the true failures for the specified number of hours
true_failures_hour = y_test_hour[index_hour + sequence_length:index_hour + sequence_length+ prediction_steps]

true_failures_with_previous_hour = np.concatenate([previous_true_failures_hour, true_failures_hour])

# Print the predicted failures
print("Predicted failures for the next 7 hours:")
print(predicted_failures_hour)

# Evaluate the predictions using Mean Squared Error
mse_predictions = np.mean((predicted_failures_hour - true_failures_hour)**2)
print(f'\nMean Squared Error for Predictions: {mse_predictions:.4f}\n')

# Evaluate the predictions using Mean Absolute Error
mae_predictions = np.mean(np.abs(predicted_failures_hour - true_failures_hour))
print(f'Mean Absolute Error for Predictions: {mae_predictions:.4f}')

# Plot predicted failures vs. true failures
plt.figure(figsize=(10, 6))
plt.plot(predicted_failures_with_previous_hour, label='Predicted Failures', marker='o')
plt.plot(true_failures_with_previous_hour, label='True Failures', marker='x')
plt.xlabel('Hours')
plt.ylabel('Number of Failures')
plt.title('Predicted Failures vs. True Failures')
plt.legend()
plt.ylim(-2, 2)
plt.grid(True)
plt.show()
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted failures for the next 7 hours:
# [0.54774994, 0.5512486, 0.55356157, 0.55532336, 0.55664045, 0.5575925, 0.5582575]
#
# Mean Squared Error for Predictions: 0.3073
#
# Mean Absolute Error for Predictions: 0.5543

# %% [markdown]
# # 30 minutes -> 7 minutes

# %%
# Extract relevant columns
df_selected = df[['timestamp', 'state'] + selected_features].copy()

# Encode the target variable 'state' to binary (0 for "COMPLETED", 1 otherwise)
df_selected['target'] = (df_selected['state'] != 'COMPLETED').astype(int)

# Drop the original 'state' column
df_selected.drop('state', axis=1, inplace=True)

# Normalize selected features
scaler = MinMaxScaler()
df_selected[selected_features] = scaler.fit_transform(df_selected[selected_features])

# %%
# Prepare data
data_minute = prepare_data(df_selected, time_intervals['minute'])

# Create sequences and targets
sequences_minute, targets_minute = create_sequences(data_minute, sequence_length)

# Split the data into training and testing sets
X_train_minute, X_test_minute, y_train_minute, y_test_minute = train_test_split(sequences_minute, targets_minute, test_size=0.2, random_state=1)

# Build the LSTM model
lstm_model_minute = Sequential()
lstm_model_minute.add(LSTM(50, input_shape=(X_train_minute.shape[1], X_train_minute.shape[2])))
lstm_model_minute.add(Dense(1, activation='sigmoid'))
lstm_model_minute.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

# Train the model
lstm_model_minute.fit(X_train_minute, y_train_minute, epochs=5, batch_size=16, validation_split=0.15)

# Build the TCN model
tcn_model_minute = Sequential([
    TCN(input_shape=(sequence_length, X_train_minute.shape[2])),
    Dense(1, activation='sigmoid')
])

tcn_model_minute.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

# Train the model
tcn_model_minute.fit(X_train_minute, y_train_minute, epochs=5, batch_size=32, validation_split=0.1)

# Create the hybrid model
hybrid_model_attention_min = create_attention_hybrid_model(lstm_model_minute, tcn_model_minute)

# Train the hybrid model with both LSTM and TCN data
history_min = hybrid_model_attention_min.fit([X_train_minute, X_train_minute], y_train_minute, epochs=5, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/5
# 7033/7033 [==============================] - 146s 21ms/step - loss: 6.1094e-04 - mean_squared_error: 6.1094e-04 - val_loss: 8.2227e-05 - val_mean_squared_error: 8.2227e-05
# Epoch 2/5
# 7033/7033 [==============================] - 145s 21ms/step - loss: 6.2786e-05 - mean_squared_error: 6.2786e-05 - val_loss: 4.1753e-05 - val_mean_squared_error: 4.1753e-05
# Epoch 3/5
# 7033/7033 [==============================] - 142s 20ms/step - loss: 5.7091e-05 - mean_squared_error: 5.7091e-05 - val_loss: 8.9999e-05 - val_mean_squared_error: 8.9999e-05
# Epoch 4/5
# 7033/7033 [==============================] - 151s 22ms/step - loss: 3.9644e-05 - mean_squared_error: 3.9644e-05 - val_loss: 2.4203e-05 - val_mean_squared_error: 2.4203e-05
# Epoch 5/5
# 7033/7033 [==============================] - 152s 22ms/step - loss: 4.4686e-05 - mean_squared_error: 4.4686e-05 - val_loss: 3.8382e-05 - val_mean_squared_error: 3.8382e-05
# Epoch 1/5
# 3723/3723 [==============================] - 152s 40ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 2/5
# 3723/3723 [==============================] - 149s 40ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 3/5
# 3723/3723 [==============================] - 148s 40ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 4/5
# 3723/3723 [==============================] - 149s 40ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 5/5
# 3723/3723 [==============================] - 149s 40ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 1/5
# 3723/3723 [==============================] - 162s 42ms/step - loss: 0.0604 - mean_squared_error: 0.0604 - val_loss: 0.0092 - val_mean_squared_error: 0.0092
# Epoch 2/5
# 3723/3723 [==============================] - 157s 42ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 3/5
# 3723/3723 [==============================] - 157s 42ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 8.1849e-04 - val_mean_squared_error: 8.1849e-04
# Epoch 4/5
# 3723/3723 [==============================] - 157s 42ms/step - loss: 7.0028e-04 - mean_squared_error: 7.0028e-04 - val_loss: 4.9292e-04 - val_mean_squared_error: 4.9292e-04
# Epoch 5/5
# 3723/3723 [==============================] - 157s 42ms/step - loss: 4.4442e-04 - mean_squared_error: 4.4442e-04 - val_loss: 3.2493e-04 - val_mean_squared_error: 3.2493e-04

# %% [markdown]
# ## Performance_Minute

# %%
# Evaluate the model using Mean Squared Error
mse_min = hybrid_model_attention_min.evaluate([X_test_minute, X_test_minute], y_test_minute, verbose=0)[1]
print(f'Mean Squared Error: {mse_min:.4f}\n')
# Out:
# Mean Squared Error: 0.0004

# %%
# Evaluate model on test data
y_pred_minute = hybrid_model_attention_min.predict([X_test_minute, X_test_minute])

# Calculate Root Mean Squared Error
rmse_minute = mean_squared_error(y_test_minute, y_pred_minute, squared=False)
print(f'Root Mean Squared Error (RMSE): {rmse_day:.4f}\n')

# Calculate Mean Absolute Error
mae_min = mean_absolute_error(y_test_minute, y_pred_minute)
print(f'Mean Abosolute Error: {mae_min:.4f}\n')

# Calculate R-squared
r2_min = r2_score(y_test_minute, y_pred_minute)
print(f'R-squared (R2): {r2_min:.4f}\n')
# Out:
# 1035/1035 [==============================] - 19s 18ms/step
# Root Mean Squared Error (RMSE): 0.2791
#
# Mean Abosolute Error: 0.0105
#
# R-squared (R2): 0.8235

# %% [markdown]
# ### Training and Validation Loss Plot

# %%
# Plot training and validation loss
plt.plot(history_min.history['loss'], label='Training Loss')
plt.plot(history_min.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Predicted Failures vs. True Failures Plot

# %%
index_minute = 0  # Can be any valid starting point

input_data_minute = X_test_minute[index_minute]
previous_true_failures_minute = y_test_minute[index_minute:index_minute + sequence_length]

# Make predictions
predicted_failures_minute = predict_future_failures_hybrid(hybrid_model_attention_min, input_data_minute, input_data_minute, sequence_length, prediction_steps)

predicted_failures_with_previous_minute = np.concatenate([previous_true_failures_minute, predicted_failures_minute])

# Get the true failures for the specified number of minutes
true_failures_minute = y_test_minute[index_minute:index_minute + prediction_steps]

true_failures_with_previous_minute = np.concatenate([previous_true_failures_minute, true_failures_minute])

# Print the predicted failures
print("Predicted failures for the next 7 minutes")
print(predicted_failures_minute)

# Evaluate the predictions using Mean Squared Error
mse_predictions = np.mean((predicted_failures_minute - true_failures_minute)**2)
print(f'\nMean Squared Error for Predictions: {mse_predictions:.4f}\n')

# Evaluate the predictions using Mean Absolute Error
mae_predictions = np.mean(np.abs(predicted_failures_minute - true_failures_minute))
print(f'Mean Absolute Error for Predictions: {mae_predictions:.4f}')

# Plot predicted failures vs. true failures
plt.figure(figsize=(10, 6))
plt.plot(predicted_failures_with_previous_minute, label='Predicted Failures', marker='o')
plt.plot(true_failures_with_previous_minute, label='True Failures', marker='x')
plt.xlabel('Minutes')
plt.ylabel('Number of Failures')
plt.title('Predicted Failures vs. True Failures')
plt.legend()
plt.ylim(-1, 4)
plt.grid(True)
plt.show()
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted failures for the next 7 minutes
# [0.031620514, 0.031629283, 0.03169508, 0.03173961, 0.031767223, 0.03178701, 0.031814992]
#
# Mean Squared Error for Predictions: 0.0004
#
# Mean Absolute Error for Predictions: 0.0136

# %% [markdown]
# # Comparison between Diff. Time Granularity

# %%
# Plot MSE for different time granularities
time_granularities = ['Day', 'Hour', 'Minute']
mse_values = [mse_day, mse_hour, mse_min]

plt.bar(time_granularities, mse_values)
plt.title('Comparison of LSTM Model MSE for Different Time Granularities')
plt.xlabel('Time Granularity')
plt.ylabel('Mean Squared Error (MSE)')
plt.show()

# %% [markdown]
# # Model Comparison

# %% [markdown]
# ## Attention Visualization

# %%
# Get the attention layer
attention_layer = hybrid_model_attention_day.layers[-1]  # Assuming the attention layer is the third last layer

# Check if the layer has trainable weights
if hasattr(attention_layer, 'get_weights') and len(attention_layer.get_weights()) > 0:
    attention_weights = attention_layer.get_weights()[0]
    # Visualize attention weights as needed
else:
    print("The selected layer does not have trainable weights.")

# %%
# Plot attention weights
plt.figure(figsize=(10, 6))
plt.imshow(attention_weights, cmap='hot', interpolation='nearest')
plt.xlabel('Input Sequence Time Steps')
plt.ylabel('Output Sequence Time Steps')
plt.title('Attention Weights')
plt.colorbar(label='Attention Weight')
plt.show()

# %% [markdown]
# ## Scalability and Efficiency Analysis
# ### Time and Memory Complexity Analysis

# %%
# Define a function to profile memory usage
def profile_memory(func):
    mem_usage = memory_usage((func, ()))
    return max(mem_usage)

# %%
# Measure inference time for the hybrid model
start_time_day = time.time()
hybrid_model_attention_day.predict([X_test_day, X_test_day])
end_time_day = time.time()
inference_time_hybrid_day = end_time_day - start_time_day
print("Hybrid model inference time (Day):", inference_time_hybrid_day, "seconds")

start_time_hour = time.time()
hybrid_model_attention_hour.predict([X_test_hour, X_test_hour])
end_time_hour = time.time()
inference_time_hybrid_hour = end_time_hour - start_time_hour
print("Hybrid model inference time (Hour):", inference_time_hybrid_hour, "seconds")

start_time_minute = time.time()
hybrid_model_attention_min.predict([X_test_minute, X_test_minute])
end_time_minute = time.time()
inference_time_hybrid_minute = end_time_minute - start_time_minute
print("Hybrid model inference time (Minute):", inference_time_hybrid_minute, "seconds")

# Measure memory usage during model inference
memory_usage_day = profile_memory(lambda: hybrid_model_attention_day.predict([X_test_day, X_test_day]))
print("Hybrid model memory usage (Day):", memory_usage_day, "bytes")

memory_usage_hour = profile_memory(lambda: hybrid_model_attention_hour.predict([X_test_hour, X_test_hour]))
print("Hybrid model memory usage (Hour):", memory_usage_hour, "bytes")

memory_usage_minute = profile_memory(lambda: hybrid_model_attention_min.predict([X_test_minute, X_test_minute]))
print("Hybrid model memory usage (Minute):", memory_usage_minute, "bytes")
# Out:
# 1/1 [==============================] - 0s 38ms/step
# Hybrid model inference time (Day): 0.08608102798461914 seconds
# 26/26 [==============================] - 0s 18ms/step
# Hybrid model inference time (Hour): 0.5565950870513916 seconds
# 1035/1035 [==============================] - 19s 18ms/step
# Hybrid model inference time (Minute): 19.242571115493774 seconds
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 57ms/step
# Hybrid model memory usage (Day): 4484.30078125 bytes
# 26/26 [==============================] - 1s 20ms/step
# Hybrid model memory usage (Hour): 4486.9921875 bytes
# 1035/1035 [==============================] - 17s 17ms/step
# Hybrid model memory usage (Minute): 4668.7265625 bytes

# %% [markdown]
# ## Robustness and Generalization Analysis

# %%
test_loss_day, test_accuracy_day = hybrid_model_attention_day.evaluate([X_test_day, X_test_day], y_test_day)
print("Test loss (Day):", test_loss_day)
print("Test accuracy (Day):", test_accuracy_day)

test_loss_hour, test_accuracy_hour = hybrid_model_attention_hour.evaluate([X_test_hour, X_test_hour], y_test_hour)
print("Test loss (Hour):", test_loss_hour)
print("Test accuracy (Hour):", test_accuracy_hour)

test_loss_minute, test_accuracy_minute = hybrid_model_attention_min.evaluate([X_test_minute, X_test_minute], y_test_minute)
print("Test loss (Minute):", test_loss_minute)
print("Test accuracy (Minute):", test_accuracy_minute)
# Out:
# 1/1 [==============================] - 0s 47ms/step - loss: 0.1729 - mean_squared_error: 0.1729
# Test loss (Day): 0.17292043566703796
# Test accuracy (Day): 0.17292043566703796
# 26/26 [==============================] - 1s 19ms/step - loss: 0.0724 - mean_squared_error: 0.0724
# Test loss (Hour): 0.07244129478931427
# Test accuracy (Hour): 0.07244129478931427
# 1035/1035 [==============================] - 19s 18ms/step - loss: 3.6781e-04 - mean_squared_error: 3.6781e-04
# Test loss (Minute): 0.00036781138624064624
# Test accuracy (Minute): 0.00036781138624064624
